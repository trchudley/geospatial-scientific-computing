# %% [markdown]
# # Tabular data and `pandas`

# %% [markdown]
#  - Outline of what `pandas` is
#  - Importing data
#  - Viewing data, explain structure (headers, columns, dataframe vs dataseries, etc.)
#  - Performing operations: statistics (mean, min, max, percentile, etc.).
#  - Time-series operatins (running average, etc.)
#  - Wrangling: joins, etc.

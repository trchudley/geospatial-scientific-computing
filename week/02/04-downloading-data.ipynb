# %% [markdown]
# # Downloading data

# %% [markdown]
# Potentially useful locations to download data.
#
# Here, less relevant _where_ the data comes from: you understand that csv, xlsx, etc 'tabuler data' is extensive.
#
# Instead, the important thing is to be able to manage data: e.g. ignore headers, load from excel pages, etc.
#
#  - Examples of where to download tabular data is in appendix. Maybe use an example of climate data?
#  - Use muana loa data as an example of how to import headers.
#  - Quirks of importing excel files: sheets, etc.

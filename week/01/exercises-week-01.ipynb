# %% [markdown]
# # Week 1 Exercises

# %% [markdown]
# Try and work through these exercise by adding your own code to the cells to get the desired output.
#
# You should be familiar with the key concepts in these exercises from the content in these sessions. However, in places, I may choose to introduce some additional concepts, and you may find that you will benefit from additional research, such as by Googling or asking an LLM.
#
# Within this course, you are allowed to use AI to aid you writing and debugging code, but [I wouldn't recommend it, for reasons I outline here](../../backmatter/ai.md). AI will be able to solve the questions here nearly instantly - but it won't help you understand what's going on! Learning the hard way is essential to allow us to build towards more complex uses. With a solid base understanding, your ability to query and use AI for complex problems will be more effective down the line.

# %% [markdown]
# ## Downloading the Notebook

# %% [markdown]
# You can download this notebook by clicking the 'Download' symbol above and to the right of the page title. Download it and ensure it is saved in a sensible location within your Desktop, and one you can access from your Jupyter Lab environment.
#
# Open up your command prompt/terminal and and ensure you are in the right directory (you might want to make a new one in a sensible place - e.g. `Documents/MSc/GEOMG0081/weekly_notebooks`). Activate the correct environment (run `conda activate gsc`; and then type `jupyter lab`).

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Basic Variables and Types

# %% [markdown]
# Create a list containing 6 different animals, and print out the list to the screen:

# %%
# TODO: Write your list here.

# %% [markdown]
# Write a loop which will print out each of the animals, prefixed with Species.

# %%
# TODO: Write your loop co de here.

# %% [markdown]
# Given a temperature in Kelvin, create a new variable `temp_c` that will represent the value in Celcius (i.e. the temperature in Kevlin, minus 273.15)
#
# Expected output: `Temperature in Celsius: 18.15`

# %%
temp_k = 292

# TODO: Write code to convert Kelvin to Celsius


print(f"Temperature in Celsius: {temp_c}")

# %% [markdown]
# Create a dictionary based on the following data table about Banksy artwork. The keys of the dicitonary should be the name of the artwork, and the values should be the location.
#
# | Artwork | Location |
# | - | - |
# | Girl with Balloon | London |
# | The Mild Mild West | Bristol |
# | Create Escape | Reading |
# | Swing Girl | Los Angeles |
#
# Expected output: `The Mild Mild West is located in Bristol`

# %%
# TODO: Create a dictionary called "bansky_dict" according to the table above

# Test
print(f"The Mild Mild West is located in {banksy_dict['The Mild Mild West']}.")

# %% [markdown]
# ### Type Inspection

# %% [markdown]
# Convert the provided variables to their target types so that the operations complete successfully.

# %%
num_str = "12.5"
num_int = 3
count = 42

# TODO: Convert num_str to float, add num_int to it, and cast count to str to print
combined_float = None
total_string = None

print(f"Combined float: {combined_float}")
print(f"Combined float is float: {isinstance(combined_float, float)}")
print(f"Total string: {total_string}")
print(f"Total string is str: {isinstance(total_string, str)}")

# %% [markdown]
# Target Output:
# ```
# Combined float: 15.5
# Combined float is float: True
# Total string: Item count: 42
# Total string is string: True
# ```

# %% [markdown]
# ### String maniplation

# %% [markdown]
# Extract the domain name from an email address and convert it to uppercase.
#
#  - Given: `email = "firstname.lastname@bristol.ac.uk"`
#  - Target Output: `"BRISTOL.AC.UK"`

# %%
email = "firstname.lastname@bristol.ac.uk"

# TODO: Use string slicing or .split() and string methods to extract and format the domain
domain = None

print(domain)

# %% [markdown]
# As a slightly more difficult example, extract "firstname" and "lastname" seperately, properly capitalised (the `.title()` function capitalises the first letter in every word)
#
#  - Given: `email = "firstname.lastname@bristol.ac.uk"`
#  - Target Output: `firstname: Firstname` and `lastname = Lastname`

# %%
email = "firstname.lastname@bristol.ac.uk"

# TODO: Use string slicing or .split() and string methods to extract and format the domain
firstname = None
lastname = None

print("firstname:", firstname)
print("lastname:", lastname)

# %% [markdown]
# ### Mathematical operations

# %% [markdown]
# You were introduced to a number of basic mathematical operations, including floor division (`//`) and module (`%`). Use floor division and modula operators to calculate how many full weeks are in 135 days, and how many leftover days remain:

# %%
total_days = 135

# TODO: Calculate weeks using floor division (//) and remaining days using modulo (%)
weeks = None
remaining_days = None

print(f"Weeks: {weeks}")
print(f"Remaining days: {remaining_days}")

# %% [markdown]
# Target output:
#
# ```
# Weeks: 19
# Remaining days: 2
# ```

# %% [markdown]
# ### Comparisons and Boolean Logic

# %% [markdown]
# Write a logical condition that checks if a person is eligible for a discount: they must be aged `65` or older, or be a student (`is_student = True`), and have a membership (`has_membership = True`).
#
#  - Given: `age = 22`, `is_student = True`, `has_membership = True`
#  - Target Output: `Discount eligible: True`

# %%
age = 22
is_student = True
has_membership = True

# TODO: Combine conditions using and, or, and parentheses
is_eligible = None

print(f"Discount eligible: {is_eligible}")

# %% [markdown]
# ### Modifying a list

# %% [markdown]
# Add "`orange`" as the second item to the list below.

# %%
fruits = ["apple", "banana", "cherry"]

# TODO: Add "orange" as the second item of the list

print(fruits)

# %% [markdown]
# Using list methods such as `append`, add "`strawberry`" to the end of the list, and replace "`pineapple`" with "`blueberry`".

# %%
fruits = ["apple", "banana", "cherry"]

# TODO: Modify the list using indexing and list methods


print(fruits)

# %% [markdown]
# ### Modifying a dictionary

# %% [markdown]
# Given a student record, update the "score" to 92 and add a new key "passed" set to True.
#
#  - Given: `student = {"name": "Alex", "score": 85}`
#  - Target Output: `{'name': 'Alex', 'score': 92, 'passed': True}`

# %%
student = {"name": "Alex", "score": 85}

# TODO: Update the dictionary keys


print(student)

# %% [markdown]
# Given a dictionary of item prices, update the price of "`apple`" to `1.25`, add a new item "`grape`" priced at `2.99`, and fetch the price of "`banana`".

# %%
prices = {"apple": 1.00, "banana": 0.50}

# TODO: Perform the dictionary updates and lookup
banana_price = None

print(f"Banana price: {banana_price}")
print(f"Updated dictionary: {prices}")

# %% [markdown]
# Target output:
#
# ```
# Banana price: 0.5
# Updated dictionary: {'apple': 1.25, 'banana': 0.5, 'grape': 2.99}
# ```

# %% [markdown]
# ### Conditional Logic

# %% [markdown]
# Write an `if`-`elif`-`else` structure that assigns a letter grade based on score:
#
#  - 90 or above: `"A"`
#  - 80 to 89: `"B"`
#  - Below 80: `"C"`
#  - Given: `score = 84`
#  - Target Output: `Grade: B`

# %%
score = 84
grade = None

# TODO: Write your conditional logic here


print(f"Grade: {grade}")

# %% [markdown]
# Write a conditional statement to check if a user input string is empty. If empty, assign "Guest" to username; otherwise, keep the input.
#
#  - Given:` user_input = ""`
#  -  Target Output: `Username: Guest`

# %%
user_input = ""
username = ""

# TODO: Check if user_input is empty using boolean evaluation


print(f"Username: {username}")

# %% [markdown]
# The modulo operator can be used to check whether a number is exactly divisable by another number (e.g. `16 % 2` = `0`; `21 % 9` = `0`). Write an `if`-`else` statement that assign `even = True` if the number is even, and `even = False` if not.

# %%
number = 13
even = None

# TODO: Write your conditional logic here

print(f"{number} is even: {even}")

# %% [markdown]
# ### Loops

# %% [markdown]
# Loop over the `inventory` dictionary and print items that have a stock count of less than `10`.
#
# Target output:
#
# ```
# Low stock: bananas (4)
# Low stock: oranges (8)
# ```

# %%
inventory = {"apples": 15, "bananas": 4, "oranges": 8, "pears": 20}

# TODO: Loop over inventory.items() and check quantities

# %% [markdown]
# A classic rookie Python test is the "fizzbuzz" test. This will print all number in a range, but with the following rules:
#
#  - If divisible by 3, print "Fizz"
#  - If divisible by 5, print "Buzz"
#  - If divisible by both 3 and 5, print "FizzBuzz"
#
# Otherwise, just print the number.
#
# For instance, up to 15, the output should be:
#
# ```
# 1, 2, Fizz, 4, Buzz, Fizz, 7, 8, Fizz, Buzz, 11, Fizz, 13, 14, FizzBuzz
# ```
#
# Write the necessary for

# %%
numbers = list(range(15))

# TODO: Use a for loop to iterate through the numbers and print out the number according to FizzBuzz rules

# %% [markdown]
# Iterate through numbers. Calculate the sum of only the even numbers.
#
#  - Given: numbers = `[12, 7, 19, 24, 3, 10]`
#  - Target Output: `Total sum of evens: 46`

# %%
numbers = [12, 7, 19, 24, 3, 10]
even_sum = 0

# TODO: Loop over numbers, check if even using %, and accumulate into even_sum


print(f"Total sum of evens: {even_sum}")

# %% [markdown]
# ### Functions

# %% [markdown]
# Write a function `calculate_emissions_offset(distance_km, transport_mode="car")` that calculates total CO<sub>2</sub> emissions in kilograms based on travel distance and mode of transport, then returns the required cost to offset it at £0.02 per kg of CO<sub>2</sub>.
#
# Emissions rates are as follows:
#
# | Mode | Emissions Rates (kg CO<sub>2</sub> per km) |
# | - | - |
# | `"car"` | 0.17 |
# | `"train"` | 0.04 |
# | `"flight"` | 0.25 |
#
# If a user enters a mode that is not one of `["car", "train", "flight"]`, make sure a printed warning is displayed to the user.
#
# Target Output for `calculate_emissions_offset(500, transport_mode="flight")`:
#
# ```
# Emissions: 125.0 kg CO2
# Offset Cost: $2.50
# ```

# %%
def calculate_emissions_offset(distance_km, transport_mode="car"):
    # TODO: Calculate emissions based on mode, then compute offset cost
    
    pass  # "Pass" means "do nothing" and is a placeholder for future code.

# Test call:
calculate_emissions_offset(500, transport_mode="flight")

# %% [markdown]
# Write a function `analyze_energy_grid(energy_sources)` that takes a dictionary of energy sources (in Megawatts) and returns a tuple containing:
#
#  - The total grid output.
#  - The percentage of output coming from renewables (`["solar", "wind", "hydro"]`).
#
# Target output:
#
# ```
# Total Generation: 1000 MW
# Renewable Share: 50.0%
# ```

# %%
grid_data = {"solar": 120, "wind": 280, "coal": 400, "hydro": 100, "gas": 100}

def analyze_energy_grid(energy_sources):
    # TODO: Calculate total power and sum only solar, wind, and hydro
    pass

# Test call:
total, renewable_pct = analyze_energy_grid(grid_data)

print(f"Total Generation: {total} MW")
print(f"Renewable Share: {renewable_pct}%")

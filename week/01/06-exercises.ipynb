# %% [markdown]
# # Week 1 Exercises

# %% [markdown]
# > You can download this notebook by clicking the 'Download' symbol above and to the right of the page title.
#
# Try and work through these exercise by adding your own code to the cells to get the desired output.
#
# You should be familiar with the concepts in these exercises from the content in these sessions. However, you may find that you will benefit from additional research, either by Googling or asking an LLM. Within this course, you are allowed to use AI
#
# Based on the information you have been given in this week's course content, alongside

# %% [markdown]
# # Week 1 Exercises

# %% [markdown]
# Try and work through these exercise by adding your own code to the cells to get the desired output.
#
# You should be familiar with the concepts in these exercises from the content in these sessions. However, you may find that you will benefit from additional research, either by Googling or asking an LLM. Within this course, you are allowed to use AI to aid you writing and debugging code, but [I wouldn't recommend it, for reasons I outline here](../../backmatter/ai.md). AI will be able to solve the questions here nearly instantly - but it won't help you understand what's going on. Learning the hard way is essential to allow us to build towards more complex uses -- and means that, when it really matters, your ability to query and use AI will be more effective down the line.

# %% [markdown]
# # Downloading the Notebook

# %% [markdown]
# You can download this notebook by clicking the 'Download' symbol above and to the right of the page title. Download it and ensure it is saved in a sensible location within your Desktop, and one you can access from your Jupyter Lab environment.
#
# Open up your command prompt/terminal and run Jupyter Lab (run `conda activate gsc`; and then type `jupyter lab`)
